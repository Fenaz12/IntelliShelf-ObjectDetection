# %% [markdown]
# Connect with google drive and install packages

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.2/562.2 kB 38.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.7/201.7 kB 26.7 MB/s eta 0:00:00
# ...

# %%
ROOT_DIR = "/content/gdrive/MyDrive/GOI/"

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics YOLOv8.0.90 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.5/78.2 GB disk)

# %% [markdown]
# **YOLO Detection -random image**
#
# ---

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://images.hindustantimes.com/rf/image_size_960x540/HT/p2/2019/06/26/Pictures/_6d0dcf8e-979f-11e9-b4b1-9d5290fba395.jpg' save=True
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 282MB/s]
# Ultralytics YOLOv8.0.88 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 57.7k/57.7k [00:00<00:00, 1.13MB/s]
# image 1/1 /content/_6d0dcf8e-979f-11e9-b4b1-9d5290fba395.jpg: 384x640 6 persons, 1 bicycle, 2 cars, 1 motorcycle, 2 trucks, 64.0ms
# Speed: 0.6ms preprocess, 64.0ms inference, 23.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
Image(filename='runs/detect/predict/_6d0dcf8e-979f-11e9-b4b1-9d5290fba395.jpg', height=600)

# %% [markdown]
# YOLO Custom Model Training Using Custom Data
#
# ---

# %%
# !yolo task=detect mode=train model=yolov8m.pt data={ROOT_DIR}/config.yaml epochs=40 imgsz=640
# Out:
# Ultralytics YOLOv8.0.88 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
